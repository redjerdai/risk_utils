# %%
#

# %%
import numpy
from matplotlib import pyplot
from sklearn.linear_model import LinearRegression

# %%
from risk_utils.risk_machine import RiskMachine

# %%
# Generate data

# %%
K = 10_000
N = 10_000
tt = numpy.array(numpy.arange(N))
portfolio = numpy.random.normal(loc=0.10, scale=10.00, size=(N,)).cumsum() + K
benchmark = numpy.random.normal(loc=0.01, scale=01.00, size=(N,)).cumsum() + K

# %%
pyplot.plot(tt, portfolio, 'navy', tt, benchmark, 'black')
pyplot.show()

# %%
# Run the Risk-Machine

# %%
risk_machine = RiskMachine()
risk_machine.add_benchs([benchmark])
risk_machine.add_portfolios([portfolio])
risk_machine.summary()
# Out:
# C:\Sygm\RAMP\IP-02\OSTRTA\risk_utils\risk_utils\risk_machine.py:98: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
# Calculate the rates manually

# %%
portfolio
# Out:
# array([10004.36506564, 10007.5732728 ,  9993.41348802, ...,
#        10436.37891442, 10430.22844854, 10429.98667814])

# %%
portfolio_lagged = numpy.roll(portfolio, shift=1)
portfolio_lagged
# Out:
# array([10429.98667814, 10004.36506564, 10007.5732728 , ...,
#        10412.8655201 , 10436.37891442, 10430.22844854])

# %%
portfolio_yield = portfolio / portfolio_lagged - 1
portfolio_yield = portfolio_yield[1:]
portfolio_yield
# Out:
# array([ 3.20680736e-04, -1.41490693e-03,  2.53269388e-03, ...,
#         2.25810986e-03, -5.89329492e-04, -2.31797799e-05])

# %%
benchmark
# Out:
# array([ 9999.40906158,  9998.72695015,  9998.31431062, ...,
#        10129.72937519, 10128.16787282, 10129.59059155])

# %%
benchmark_lagged = numpy.roll(benchmark, shift=1)
benchmark_lagged
# Out:
# array([10129.59059155,  9999.40906158,  9998.72695015, ...,
#        10128.32342739, 10129.72937519, 10128.16787282])

# %%
benchmark_yield = benchmark / benchmark_lagged - 1
benchmark_yield = benchmark_yield[1:]
benchmark_yield
# Out:
# array([-6.82151743e-05, -4.12692066e-05, -1.35745471e-04, ...,
#         1.38813478e-04, -1.54150453e-04,  1.40471480e-04])

# %%
portfolio_yield.reshape(-1, 1)
# Out:
# array([[ 3.20680736e-04],
#        [-1.41490693e-03],
#        [ 2.53269388e-03],
#        ...,
#        [ 2.25810986e-03],
#        [-5.89329492e-04],
#        [-2.31797799e-05]])

# %%
lm = LinearRegression(fit_intercept=True)
lm.fit(portfolio_yield.reshape(-1, 1), benchmark_yield)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lm.intercept_
# Out:
# 1.3001829996812643e-06

# %%
lm.coef_
# Out:
# array([-0.00034892])

# %%
treynor_ratio = (portfolio_yield - benchmark_yield).mean() / lm.coef_[0]
treynor_ratio
# Out:
# -0.009533338904854458

# %%
semi_deviation = (benchmark_yield[benchmark_yield < benchmark_yield.mean()]).std(ddof=1)
semi_deviation
# Out:
# 6.0025517446272146e-05

# %%
sortino_ratio = (portfolio_yield - benchmark_yield).mean() / semi_deviation
sortino_ratio
# Out:
# 0.05541576480476209

# %%
sharpe_ratio = (portfolio_yield - benchmark_yield).mean() / (portfolio_yield - benchmark_yield).std(ddof=1)
sharpe_ratio
# Out:
# 0.003454942768606226

# %%
value_at_risk = numpy.quantile(a=portfolio_yield, q=(1 - 0.99))
value_at_risk
# Out:
# -0.002246160386923554

# %%
conditional_value_at_risk = (portfolio_yield[portfolio_yield < value_at_risk]).mean()
conditional_value_at_risk
# Out:
# -0.00255559493715107
